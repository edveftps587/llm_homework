# %%
from transformers import pipeline
from transformers import AutoTokenizer

# %% [markdown]
# # Sentiment Analysis

# %%
sentences = [
    "今天天气真好，我感觉心情很愉快！",
    "这次的考试太难了，我觉得自己肯定不会及格。",
    "我对这个新闻没有什么特别的感觉。",
    "他们的服务态度实在太差了，让我非常生气。",
    "我终于完成了这个项目，感到非常的满足和自豪。",
    "这部电影真的很无聊，我看着看着就睡着了。",
    "今天遇到了老朋友，感觉就像回到了过去。",
    "工作上的压力真的很大，让我感到焦虑不安。",
    "我今天尝试了新菜谱，家人都说很好吃。",
    "这个消息听起来太假了，我一点也不信。"
]

models = [
    "lxyuan/distilbert-base-multilingual-cased-sentiments-student",
    "bardsai/finance-sentiment-zh-base",
    "IDEA-CCNL/Erlangshen-Roberta-110M-Sentiment"
]

# %%
answers = [
    True, False, False, False, True, False, True, False, True, False
]

def check(result, _answers):
    f = []
    for r in result:
        if r.get('label') == 'positive':
            f.append(True)
        else:
            f.append(False)
    return [i==j for i, j in zip(f, _answers)]

# %%
for model in models:
    print(f"【测试】【{model}】")
    pipe = pipeline(task="sentiment-analysis", model=model)
    result = pipe(sentences)
    check_result = check(result, answers)
    for i, j, k in zip(sentences, result, check_result):
        print(i, j, k)
    print("正确数量：", sum(check_result))
    print("-----------------------------------------------------------------------------")
# Out:
# 【测试】【lxyuan/distilbert-base-multilingual-cased-sentiments-student】
# 今天天气真好，我感觉心情很愉快！ {'label': 'positive', 'score': 0.9922294020652771} True
# 这次的考试太难了，我觉得自己肯定不会及格。 {'label': 'negative', 'score': 0.8550916314125061} True
# 我对这个新闻没有什么特别的感觉。 {'label': 'neutral', 'score': 0.9213656783103943} True
# 他们的服务态度实在太差了，让我非常生气。 {'label': 'negative', 'score': 0.9857802987098694} True
# 我终于完成了这个项目，感到非常的满足和自豪。 {'label': 'positive', 'score': 0.9948790073394775} True
# 这部电影真的很无聊，我看着看着就睡着了。 {'label': 'negative', 'score': 0.7081538438796997} True
# 今天遇到了老朋友，感觉就像回到了过去。 {'label': 'negative', 'score': 0.4166187345981598} False
# 工作上的压力真的很大，让我感到焦虑不安。 {'label': 'negative', 'score': 0.8652476668357849} True
# 我今天尝试了新菜谱，家人都说很好吃。 {'label': 'positive', 'score': 0.9487581253051758} True
# 这个消息听起来太假了，我一点也不信。 {'label': 'negative', 'score': 0.8587807416915894} True
# 正确数量： 9
# -----------------------------------------------------------------------------
# 【测试】【bardsai/finance-sentiment-zh-base】
# 今天天气真好，我感觉心情很愉快！ {'label': 'positive', 'score': 0.9999778270721436} True
# 这次的考试太难了，我觉得自己肯定不会及格。 {'label': 'negative', 'score': 0.999863862991333} True
# 我对这个新闻没有什么特别的感觉。 {'label': 'neutral', 'score': 0.9999809265136719} True
# 他们的服务态度实在太差了，让我非常生气。 {'label': 'negative', 'score': 0.9996640682220459} True
# 我终于完成了这个项目，感到非常的满足和自豪。 {'label': 'positive', 'score': 0.9999783039093018} True
# 这部电影真的很无聊，我看着看着就睡着了。 {'label': 'negative', 'score': 0.9968774318695068} True
# 今天遇到了老朋友，感觉就像回到了过去。 {'label': 'neutral', 'score': 0.9999737739562988} False
# 工作上的压力真的很大，让我感到焦虑不安。 {'label': 'negative', 'score': 0.9999279975891113} True
# 我今天尝试了新菜谱，家人都说很好吃。 {'label': 'positive', 'score': 0.9997097849845886} True
# 这个消息听起来太假了，我一点也不信。 {'label': 'neutral', 'score': 0.9995405673980713} True
# 正确数量： 9
# -----------------------------------------------------------------------------
# 【测试】【IDEA-CCNL/Erlangshen-Roberta-110M-Sentiment】
# 今天天气真好，我感觉心情很愉快！ {'label': 'Positive', 'score': 0.9689871668815613} False
# 这次的考试太难了，我觉得自己肯定不会及格。 {'label': 'Positive', 'score': 0.9715316295623779} True
# 我对这个新闻没有什么特别的感觉。 {'label': 'Negative', 'score': 0.6044668555259705} True
# 他们的服务态度实在太差了，让我非常生气。 {'label': 'Negative', 'score': 0.9979190230369568} True
# 我终于完成了这个项目，感到非常的满足和自豪。 {'label': 'Positive', 'score': 0.986748993396759} False
# 这部电影真的很无聊，我看着看着就睡着了。 {'label': 'Negative', 'score': 0.9989049434661865} True
# 今天遇到了老朋友，感觉就像回到了过去。 {'label': 'Positive', 'score': 0.9529678225517273} False
# 工作上的压力真的很大，让我感到焦虑不安。 {'label': 'Negative', 'score': 0.7078747749328613} True
# 我今天尝试了新菜谱，家人都说很好吃。 {'label': 'Positive', 'score': 0.996988832950592} False
# 这个消息听起来太假了，我一点也不信。 {'label': 'Negative', 'score': 0.998933732509613} True
# 正确数量： 6
# -----------------------------------------------------------------------------

# %% [markdown]
# # NER

# %%
ner_sentences = [
    "明天下午三点，张伟将在北京的国家大剧院举行一场钢琴音乐会。",
    "微软公司计划于2024年在纽约市推出其最新的操作系统。",
    "《哈利·波特与密室》是J.K.罗琳所著的第二部小说，于1998年7月在英国出版。",
    "玛丽和约翰计划下周去巴黎度蜜月，并计划参观埃菲尔铁塔。",
    "印度尼西亚的巴厘岛是一个受欢迎的旅游目的地，以其美丽的海滩和独特的文化而闻名。",
    "2023年，中国的国家航天局成功发射了嫦娥五号探测器，前往月球采集样本。",
    "《纽约时报》昨日报导了美国总统对最近的经济危机的回应。",
    "英格兰国家足球队计划于明年六月在伦敦的温布利体育场参加欧洲冠军联赛决赛。",
    "诺贝尔物理学奖于2023年授予了两位科学家，他们对量子通信的贡献具有开创性意义。",
    "李华昨天在阿里巴巴集团总部参加了一次关于电子商务创新的研讨会。",
]

ner_models = [
    "ckiplab/bert-base-chinese-ner",
    "gyr66/bert-base-chinese-finetuned-ner",
    "ckiplab/albert-base-chinese-ner"
]

# %%
def handle_ner_result(preds):
    preds = [
    {
        "entity": pred["entity"],
        "score": round(pred["score"], 4),
        "index": pred["index"],
        "word": pred["word"],
        "start": pred["start"],
        "end": pred["end"],
    }
    for pred in preds]

# %%
for model in ner_models:
    print(f"【测试】【{model}】")
    pipe = pipeline(task="ner", model=model, grouped_entities=True)
    for ns in ner_sentences:
        print('【测试语句】', ns)
        result = pipe(ns)
        print(*result, sep="\n")
    print("-----------------------------------------------------------------------------")
# Out:
# 【测试】【ckiplab/bert-base-chinese-ner】
# /home/da_Ops01/anaconda3/envs/llm/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# 【测试语句】 明天下午三点，张伟将在北京的国家大剧院举行一场钢琴音乐会。
# {'entity_group': 'DATE', 'score': 0.99976057, 'word': '明', 'start': 0, 'end': 1}
# {'entity_group': 'DATE', 'score': 0.9994923, 'word': '天', 'start': 1, 'end': 2}
# {'entity_group': 'TIME', 'score': 0.9998896, 'word': '下 午 三', 'start': 2, 'end': 5}
# {'entity_group': 'TIME', 'score': 0.99999905, 'word': '点', 'start': 5, 'end': 6}
# {'entity_group': 'PERSON', 'score': 0.9999994, 'word': '张', 'start': 7, 'end': 8}
# {'entity_group': 'PERSON', 'score': 0.9999995, 'word': '伟', 'start': 8, 'end': 9}
# {'entity_group': 'GPE', 'score': 0.99999917, 'word': '北', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.99999917, 'word': '京', 'start': 12, 'end': 13}
# {'entity_group': 'FAC', 'score': 0.99999803, 'word': '国 家 大 剧', 'start': 14, 'end': 18}
# {'entity_group': 'FAC', 'score': 0.9999981, 'word': '院', 'start': 18, 'end': 19}
# 【测试语句】 微软公司计划于2024年在纽约市推出其最新的操作系统。
# {'entity_group': 'ORG', 'score': 0.99999887, 'word': '微 软 公', 'start': 0, 'end': 3}
# {'entity_group': 'ORG', 'score': 0.99999905, 'word': '司', 'start': 3, 'end': 4}
# {'entity_group': 'DATE', 'score': 0.99999917, 'word': '2024', 'start': 7, 'end': 11}
# {'entity_group': 'DATE', 'score': 0.9999994, 'word': '年', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.99999917, 'word': '纽 约', 'start': 13, 'end': 15}
# {'entity_group': 'GPE', 'score': 0.9999994, 'word': '市', 'start': 15, 'end': 16}
# 【测试语句】 《哈利·波特与密室》是J.K.罗琳所著的第二部小说，于1998年7月在英国出版。
# {'entity_group': 'WORK_OF_ART', 'score': 0.9999971, 'word': '哈 利 · 波 特 与 密', 'start': 1, 'end': 8}
# {'entity_group': 'WORK_OF_ART', 'score': 0.9999974, 'word': '室', 'start': 8, 'end': 9}
# {'entity_group': 'PERSON', 'score': 0.9999989, 'word': 'J. K. 罗', 'start': 11, 'end': 16}
# {'entity_group': 'PERSON', 'score': 0.9999994, 'word': '琳', 'start': 16, 'end': 17}
# {'entity_group': 'ORDINAL', 'score': 1.0, 'word': '第', 'start': 20, 'end': 21}
# {'entity_group': 'ORDINAL', 'score': 0.99999964, 'word': '二', 'start': 21, 'end': 22}
# {'entity_group': 'DATE', 'score': 0.9999804, 'word': '1998 年 7', 'start': 27, 'end': 33}
# {'entity_group': 'DATE', 'score': 0.9999993, 'word': '月', 'start': 33, 'end': 34}
# {'entity_group': 'GPE', 'score': 0.99999905, 'word': '英', 'start': 35, 'end': 36}
# {'entity_group': 'GPE', 'score': 0.9999993, 'word': '国', 'start': 36, 'end': 37}
# 【测试语句】 玛丽和约翰计划下周去巴黎度蜜月，并计划参观埃菲尔铁塔。
# {'entity_group': 'PERSON', 'score': 0.9999994, 'word': '玛', 'start': 0, 'end': 1}
# {'entity_group': 'PERSON', 'score': 0.99999774, 'word': '丽', 'start': 1, 'end': 2}
# {'entity_group': 'PERSON', 'score': 0.9999994, 'word': '约', 'start': 3, 'end': 4}
# {'entity_group': 'PERSON', 'score': 0.9999981, 'word': '翰', 'start': 4, 'end': 5}
# {'entity_group': 'DATE', 'score': 0.9999857, 'word': '下', 'start': 7, 'end': 8}
# {'entity_group': 'DATE', 'score': 0.9999845, 'word': '周', 'start': 8, 'end': 9}
# {'entity_group': 'GPE', 'score': 0.9999993, 'word': '巴', 'start': 10, 'end': 11}
# {'entity_group': 'GPE', 'score': 0.99999905, 'word': '黎', 'start': 11, 'end': 12}
# {'entity_group': 'FAC', 'score': 0.9999981, 'word': '埃 菲 尔 铁', 'start': 21, 'end': 25}
# {'entity_group': 'FAC', 'score': 0.9999982, 'word': '塔', 'start': 25, 'end': 26}
# 【测试语句】 印度尼西亚的巴厘岛是一个受欢迎的旅游目的地，以其美丽的海滩和独特的文化而闻名。
# {'entity_group': 'GPE', 'score': 0.99999905, 'word': '印 度 尼 西', 'start': 0, 'end': 4}
# {'entity_group': 'GPE', 'score': 0.9999993, 'word': '亚', 'start': 4, 'end': 5}
# {'entity_group': 'LOC', 'score': 0.99999774, 'word': '巴 厘', 'start': 6, 'end': 8}
# {'entity_group': 'LOC', 'score': 0.9999974, 'word': '岛', 'start': 8, 'end': 9}
# 【测试语句】 2023年，中国的国家航天局成功发射了嫦娥五号探测器，前往月球采集样本。
# {'entity_group': 'DATE', 'score': 0.99999905, 'word': '2023', 'start': 0, 'end': 4}
# {'entity_group': 'DATE', 'score': 0.9999993, 'word': '年', 'start': 4, 'end': 5}
# {'entity_group': 'GPE', 'score': 0.9999932, 'word': '中', 'start': 6, 'end': 7}
# {'entity_group': 'GPE', 'score': 0.99999, 'word': '国', 'start': 7, 'end': 8}
# {'entity_group': 'ORG', 'score': 0.99999887, 'word': '国 家 航 天', 'start': 9, 'end': 13}
# {'entity_group': 'ORG', 'score': 0.99999917, 'word': '局', 'start': 13, 'end': 14}
# {'entity_group': 'CARDINAL', 'score': 0.4787193, 'word': '五', 'start': 21, 'end': 22}
# {'entity_group': 'LOC', 'score': 0.9965636, 'word': '月', 'start': 29, 'end': 30}
# {'entity_group': 'LOC', 'score': 0.99272984, 'word': '球', 'start': 30, 'end': 31}
# 【测试语句】 《纽约时报》昨日报导了美国总统对最近的经济危机的回应。
# {'entity_group': 'ORG', 'score': 0.9999986, 'word': '纽 约 时', 'start': 1, 'end': 4}
# {'entity_group': 'ORG', 'score': 0.9999982, 'word': '报', 'start': 4, 'end': 5}
# {'entity_group': 'DATE', 'score': 0.9999976, 'word': '昨', 'start': 6, 'end': 7}
# {'entity_group': 'DATE', 'score': 0.9999968, 'word': '日', 'start': 7, 'end': 8}
# {'entity_group': 'GPE', 'score': 0.53078854, 'word': '美', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.6394955, 'word': '国', 'start': 12, 'end': 13}
# 【测试语句】 英格兰国家足球队计划于明年六月在伦敦的温布利体育场参加欧洲冠军联赛决赛。
# {'entity_group': 'ORG', 'score': 0.99856937, 'word': '英 格 兰 国 家 足 球', 'start': 0, 'end': 7}
# {'entity_group': 'ORG', 'score': 0.99999833, 'word': '队', 'start': 7, 'end': 8}
# {'entity_group': 'DATE', 'score': 0.9999986, 'word': '明 年 六', 'start': 11, 'end': 14}
# {'entity_group': 'DATE', 'score': 0.99999917, 'word': '月', 'start': 14, 'end': 15}
# {'entity_group': 'GPE', 'score': 0.9999989, 'word': '伦', 'start': 16, 'end': 17}
# {'entity_group': 'GPE', 'score': 0.99999845, 'word': '敦', 'start': 17, 'end': 18}
# {'entity_group': 'FAC', 'score': 0.99999744, 'word': '温 布 利 体 育', 'start': 19, 'end': 24}
# {'entity_group': 'FAC', 'score': 0.99999833, 'word': '场', 'start': 24, 'end': 25}
# {'entity_group': 'EVENT', 'score': 0.99942845, 'word': '欧', 'start': 27, 'end': 28}
# {'entity_group': 'EVENT', 'score': 0.72763616, 'word': '洲', 'start': 28, 'end': 29}
# {'entity_group': 'EVENT', 'score': 0.9996911, 'word': '联', 'start': 31, 'end': 32}
# {'entity_group': 'EVENT', 'score': 0.9996698, 'word': '赛', 'start': 32, 'end': 33}
# 【测试语句】 诺贝尔物理学奖于2023年授予了两位科学家，他们对量子通信的贡献具有开创性意义。
# {'entity_group': 'WORK_OF_ART', 'score': 0.9999972, 'word': '诺 贝 尔 物 理 学', 'start': 0, 'end': 6}
# {'entity_group': 'WORK_OF_ART', 'score': 0.99999774, 'word': '奖', 'start': 6, 'end': 7}
# {'entity_group': 'DATE', 'score': 0.99999917, 'word': '2023', 'start': 8, 'end': 12}
# {'entity_group': 'DATE', 'score': 0.9999993, 'word': '年', 'start': 12, 'end': 13}
# {'entity_group': 'CARDINAL', 'score': 0.999982, 'word': '两', 'start': 16, 'end': 17}
# 【测试语句】 李华昨天在阿里巴巴集团总部参加了一次关于电子商务创新的研讨会。
# {'entity_group': 'PERSON', 'score': 0.99999917, 'word': '李', 'start': 0, 'end': 1}
# {'entity_group': 'PERSON', 'score': 0.9999995, 'word': '华', 'start': 1, 'end': 2}
# {'entity_group': 'DATE', 'score': 0.99999726, 'word': '昨', 'start': 2, 'end': 3}
# {'entity_group': 'DATE', 'score': 0.999998, 'word': '天', 'start': 3, 'end': 4}
# {'entity_group': 'ORG', 'score': 0.99998504, 'word': '阿 里 巴 巴 集', 'start': 5, 'end': 10}
# {'entity_group': 'ORG', 'score': 0.99998343, 'word': '团', 'start': 10, 'end': 11}
# -----------------------------------------------------------------------------
# 【测试】【gyr66/bert-base-chinese-finetuned-ner】
# 【测试语句】 明天下午三点，张伟将在北京的国家大剧院举行一场钢琴音乐会。
# {'entity_group': 'name', 'score': 0.9999278, 'word': '张 伟', 'start': 7, 'end': 9}
# {'entity_group': 'address', 'score': 0.9998121, 'word': '北 京', 'start': 11, 'end': 13}
# {'entity_group': 'scene', 'score': 0.9745685, 'word': '国 家 大 剧 院', 'start': 14, 'end': 19}
# 【测试语句】 微软公司计划于2024年在纽约市推出其最新的操作系统。
# {'entity_group': 'company', 'score': 0.9998267, 'word': '微 软 公 司', 'start': 0, 'end': 4}
# {'entity_group': 'address', 'score': 0.99989396, 'word': '纽 约 市', 'start': 13, 'end': 16}
# 【测试语句】 《哈利·波特与密室》是J.K.罗琳所著的第二部小说，于1998年7月在英国出版。
# {'entity_group': 'book', 'score': 0.9997614, 'word': '《 哈 利 · 波 特 与 密 室 》', 'start': 0, 'end': 10}
# {'entity_group': 'name', 'score': 0.99984527, 'word': 'J. K. 罗 琳', 'start': 11, 'end': 17}
# {'entity_group': 'address', 'score': 0.9981556, 'word': '英 国', 'start': 35, 'end': 37}
# 【测试语句】 玛丽和约翰计划下周去巴黎度蜜月，并计划参观埃菲尔铁塔。
# {'entity_group': 'name', 'score': 0.9998743, 'word': '玛 丽', 'start': 0, 'end': 2}
# {'entity_group': 'name', 'score': 0.99987537, 'word': '约 翰', 'start': 3, 'end': 5}
# {'entity_group': 'address', 'score': 0.9997852, 'word': '巴 黎', 'start': 10, 'end': 12}
# {'entity_group': 'scene', 'score': 0.99978, 'word': '埃 菲 尔 铁 塔', 'start': 21, 'end': 26}
# 【测试语句】 印度尼西亚的巴厘岛是一个受欢迎的旅游目的地，以其美丽的海滩和独特的文化而闻名。
# {'entity_group': 'address', 'score': 0.99976385, 'word': '印 度 尼 西 亚', 'start': 0, 'end': 5}
# {'entity_group': 'scene', 'score': 0.99975663, 'word': '巴 厘 岛', 'start': 6, 'end': 9}
# 【测试语句】 2023年，中国的国家航天局成功发射了嫦娥五号探测器，前往月球采集样本。
# {'entity_group': 'address', 'score': 0.95265067, 'word': '中 国', 'start': 6, 'end': 8}
# {'entity_group': 'government', 'score': 0.9998814, 'word': '国 家 航 天 局', 'start': 9, 'end': 14}
# {'entity_group': 'scene', 'score': 0.42164722, 'word': '嫦', 'start': 19, 'end': 20}
# {'entity_group': 'game', 'score': 0.7447513, 'word': '娥 五 号 探 测 器', 'start': 20, 'end': 26}
# {'entity_group': 'address', 'score': 0.99960405, 'word': '月 球', 'start': 29, 'end': 31}
# 【测试语句】 《纽约时报》昨日报导了美国总统对最近的经济危机的回应。
# {'entity_group': 'book', 'score': 0.9999151, 'word': '《 纽 约 时 报 》', 'start': 0, 'end': 6}
# {'entity_group': 'position', 'score': 0.99337244, 'word': '美 国 总 统', 'start': 11, 'end': 15}
# 【测试语句】 英格兰国家足球队计划于明年六月在伦敦的温布利体育场参加欧洲冠军联赛决赛。
# {'entity_group': 'organization', 'score': 0.9999124, 'word': '英 格 兰 国 家 足 球 队', 'start': 0, 'end': 8}
# {'entity_group': 'address', 'score': 0.9884522, 'word': '伦 敦 的 温 布 利 体 育 场', 'start': 16, 'end': 25}
# {'entity_group': 'organization', 'score': 0.7372669, 'word': '欧 洲 冠 军', 'start': 27, 'end': 31}
# 【测试语句】 诺贝尔物理学奖于2023年授予了两位科学家，他们对量子通信的贡献具有开创性意义。
# {'entity_group': 'name', 'score': 0.9998283, 'word': '诺 贝 尔', 'start': 0, 'end': 3}
# {'entity_group': 'position', 'score': 0.99975365, 'word': '科 学 家', 'start': 18, 'end': 21}
# 【测试语句】 李华昨天在阿里巴巴集团总部参加了一次关于电子商务创新的研讨会。
# {'entity_group': 'name', 'score': 0.99991935, 'word': '李 华', 'start': 0, 'end': 2}
# {'entity_group': 'company', 'score': 0.99993515, 'word': '阿 里 巴 巴 集 团', 'start': 5, 'end': 11}
# {'entity_group': 'company', 'score': 0.9533174, 'word': '部', 'start': 12, 'end': 13}
# -----------------------------------------------------------------------------
# 【测试】【ckiplab/albert-base-chinese-ner】
# 【测试语句】 明天下午三点，张伟将在北京的国家大剧院举行一场钢琴音乐会。
# {'entity_group': 'DATE', 'score': 0.99993885, 'word': '明', 'start': 0, 'end': 1}
# {'entity_group': 'DATE', 'score': 0.9999584, 'word': '天', 'start': 1, 'end': 2}
# {'entity_group': 'TIME', 'score': 0.9999924, 'word': '下 午 三', 'start': 2, 'end': 5}
# {'entity_group': 'TIME', 'score': 0.99999166, 'word': '点', 'start': 5, 'end': 6}
# {'entity_group': 'PERSON', 'score': 0.9999875, 'word': '张', 'start': 7, 'end': 8}
# {'entity_group': 'PERSON', 'score': 0.99998415, 'word': '伟', 'start': 8, 'end': 9}
# {'entity_group': 'GPE', 'score': 0.9999713, 'word': '北', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.99991095, 'word': '京', 'start': 12, 'end': 13}
# {'entity_group': 'FAC', 'score': 0.9999218, 'word': '国 家 大 剧', 'start': 14, 'end': 18}
# {'entity_group': 'FAC', 'score': 0.9993123, 'word': '院', 'start': 18, 'end': 19}
# 【测试语句】 微软公司计划于2024年在纽约市推出其最新的操作系统。
# {'entity_group': 'ORG', 'score': 0.9999679, 'word': '微 软 公', 'start': 0, 'end': 3}
# {'entity_group': 'ORG', 'score': 0.99996734, 'word': '司', 'start': 3, 'end': 4}
# {'entity_group': 'DATE', 'score': 0.9999903, 'word': '2024', 'start': 7, 'end': 11}
# {'entity_group': 'DATE', 'score': 0.99999404, 'word': '年', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.99756026, 'word': '纽 约', 'start': 13, 'end': 15}
# {'entity_group': 'GPE', 'score': 0.99678, 'word': '市', 'start': 15, 'end': 16}
# 【测试语句】 《哈利·波特与密室》是J.K.罗琳所著的第二部小说，于1998年7月在英国出版。
# {'entity_group': 'WORK_OF_ART', 'score': 0.99997365, 'word': '哈 利 · 波 特 与 密', 'start': 1, 'end': 8}
# {'entity_group': 'WORK_OF_ART', 'score': 0.9999784, 'word': '室', 'start': 8, 'end': 9}
# {'entity_group': 'PERSON', 'score': 0.9999814, 'word': 'J. K. 罗', 'start': 11, 'end': 16}
# {'entity_group': 'PERSON', 'score': 0.9999844, 'word': '琳', 'start': 16, 'end': 17}
# {'entity_group': 'ORDINAL', 'score': 0.9999993, 'word': '第', 'start': 20, 'end': 21}
# {'entity_group': 'ORDINAL', 'score': 0.9999982, 'word': '二', 'start': 21, 'end': 22}
# {'entity_group': 'DATE', 'score': 0.99998945, 'word': '1998 年 7', 'start': 27, 'end': 33}
# {'entity_group': 'DATE', 'score': 0.9999865, 'word': '月', 'start': 33, 'end': 34}
# {'entity_group': 'GPE', 'score': 0.99998176, 'word': '英', 'start': 35, 'end': 36}
# {'entity_group': 'GPE', 'score': 0.9999796, 'word': '国', 'start': 36, 'end': 37}
# 【测试语句】 玛丽和约翰计划下周去巴黎度蜜月，并计划参观埃菲尔铁塔。
# {'entity_group': 'PERSON', 'score': 0.99999595, 'word': '玛', 'start': 0, 'end': 1}
# {'entity_group': 'PERSON', 'score': 0.9999949, 'word': '丽', 'start': 1, 'end': 2}
# {'entity_group': 'PERSON', 'score': 0.9999941, 'word': '约 翰', 'start': 3, 'end': 5}
# {'entity_group': 'PERSON', 'score': 0.99999654, 'word': '计', 'start': 5, 'end': 6}
# {'entity_group': 'GPE', 'score': 0.9999931, 'word': '巴', 'start': 10, 'end': 11}
# {'entity_group': 'GPE', 'score': 0.99999535, 'word': '黎', 'start': 11, 'end': 12}
# {'entity_group': 'FAC', 'score': 0.99995184, 'word': '埃 菲 尔 铁', 'start': 21, 'end': 25}
# {'entity_group': 'FAC', 'score': 0.999951, 'word': '塔', 'start': 25, 'end': 26}
# 【测试语句】 印度尼西亚的巴厘岛是一个受欢迎的旅游目的地，以其美丽的海滩和独特的文化而闻名。
# {'entity_group': 'GPE', 'score': 0.72783744, 'word': '印 度 尼 西', 'start': 0, 'end': 4}
# {'entity_group': 'GPE', 'score': 0.7250054, 'word': '亚', 'start': 4, 'end': 5}
# {'entity_group': 'LOC', 'score': 0.99997216, 'word': '巴 厘', 'start': 6, 'end': 8}
# {'entity_group': 'LOC', 'score': 0.999974, 'word': '岛', 'start': 8, 'end': 9}
# 【测试语句】 2023年，中国的国家航天局成功发射了嫦娥五号探测器，前往月球采集样本。
# {'entity_group': 'DATE', 'score': 0.999967, 'word': '2023', 'start': 0, 'end': 4}
# {'entity_group': 'DATE', 'score': 0.99995625, 'word': '年', 'start': 4, 'end': 5}
# {'entity_group': 'GPE', 'score': 0.9995633, 'word': '中', 'start': 6, 'end': 7}
# {'entity_group': 'GPE', 'score': 0.9996124, 'word': '国', 'start': 7, 'end': 8}
# {'entity_group': 'ORG', 'score': 0.99999297, 'word': '国 家 航 天', 'start': 9, 'end': 13}
# {'entity_group': 'ORG', 'score': 0.9999962, 'word': '局', 'start': 13, 'end': 14}
# {'entity_group': 'LOC', 'score': 0.60436106, 'word': '月', 'start': 29, 'end': 30}
# 【测试语句】 《纽约时报》昨日报导了美国总统对最近的经济危机的回应。
# {'entity_group': 'ORG', 'score': 0.9999676, 'word': '纽 约 时', 'start': 1, 'end': 4}
# {'entity_group': 'ORG', 'score': 0.9999585, 'word': '报', 'start': 4, 'end': 5}
# {'entity_group': 'TIME', 'score': 0.8377295, 'word': '昨', 'start': 6, 'end': 7}
# {'entity_group': 'TIME', 'score': 0.6320381, 'word': '日', 'start': 7, 'end': 8}
# {'entity_group': 'GPE', 'score': 0.99878544, 'word': '美', 'start': 11, 'end': 12}
# {'entity_group': 'GPE', 'score': 0.99978155, 'word': '国', 'start': 12, 'end': 13}
# 【测试语句】 英格兰国家足球队计划于明年六月在伦敦的温布利体育场参加欧洲冠军联赛决赛。
# {'entity_group': 'ORG', 'score': 0.7823084, 'word': '英 格', 'start': 0, 'end': 2}
# {'entity_group': 'GPE', 'score': 0.64446044, 'word': '兰', 'start': 2, 'end': 3}
# {'entity_group': 'ORG', 'score': 0.9998518, 'word': '国 家 足 球', 'start': 3, 'end': 7}
# {'entity_group': 'ORG', 'score': 0.9999559, 'word': '队', 'start': 7, 'end': 8}
# {'entity_group': 'DATE', 'score': 0.9999898, 'word': '明 年 六', 'start': 11, 'end': 14}
# {'entity_group': 'DATE', 'score': 0.99998534, 'word': '月', 'start': 14, 'end': 15}
# {'entity_group': 'GPE', 'score': 0.9999722, 'word': '伦', 'start': 16, 'end': 17}
# {'entity_group': 'GPE', 'score': 0.9999758, 'word': '敦', 'start': 17, 'end': 18}
# {'entity_group': 'FAC', 'score': 0.9999819, 'word': '温 布 利 体 育', 'start': 19, 'end': 24}
# {'entity_group': 'FAC', 'score': 0.9999608, 'word': '场', 'start': 24, 'end': 25}
# {'entity_group': 'EVENT', 'score': 0.8980049, 'word': '欧 洲 冠 军', 'start': 27, 'end': 31}
# {'entity_group': 'EVENT', 'score': 0.74010456, 'word': '赛', 'start': 32, 'end': 33}
# 【测试语句】 诺贝尔物理学奖于2023年授予了两位科学家，他们对量子通信的贡献具有开创性意义。
# {'entity_group': 'WORK_OF_ART', 'score': 0.9999693, 'word': '诺 贝 尔 物 理 学', 'start': 0, 'end': 6}
# {'entity_group': 'WORK_OF_ART', 'score': 0.99997187, 'word': '奖', 'start': 6, 'end': 7}
# {'entity_group': 'DATE', 'score': 0.999984, 'word': '2023', 'start': 8, 'end': 12}
# {'entity_group': 'DATE', 'score': 0.9999075, 'word': '年', 'start': 12, 'end': 13}
# {'entity_group': 'CARDINAL', 'score': 0.9999944, 'word': '两', 'start': 16, 'end': 17}
# 【测试语句】 李华昨天在阿里巴巴集团总部参加了一次关于电子商务创新的研讨会。
# {'entity_group': 'PERSON', 'score': 0.9999944, 'word': '李', 'start': 0, 'end': 1}
# {'entity_group': 'PERSON', 'score': 0.99999404, 'word': '华', 'start': 1, 'end': 2}
# {'entity_group': 'DATE', 'score': 0.99996865, 'word': '昨', 'start': 2, 'end': 3}
# {'entity_group': 'DATE', 'score': 0.99996006, 'word': '天', 'start': 3, 'end': 4}
# {'entity_group': 'FAC', 'score': 0.9998752, 'word': '阿 里 巴 巴 集 团 总', 'start': 5, 'end': 12}
# {'entity_group': 'FAC', 'score': 0.9999056, 'word': '部', 'start': 12, 'end': 13}
# -----------------------------------------------------------------------------

# %% [markdown]
# # Summarization

# %%
raw_text_for_sum = (
    """中国，全称中华人民共和国，是位于东亚的一个国家，拥有世界上最多的人口。它的历史可以追溯到几千年前，是世界上最古老的文明之一，拥有丰富的文化遗产和传统。中国的地理特征非常多样，从东部的沿海平原到西部的高山和高原，如青藏高原和喜马拉雅山脉。
中国的政治体制是社会主义共和国，由中国共产党领导。首都是北京，其他主要城市包括上海、广州和深圳。中国经济在过去几十年里迅速发展，现在是世界上最大的经济体之一。它在制造业、科技和贸易方面具有显著地位。
中国的文化非常丰富多彩，包括传统的文学、音乐、舞蹈、戏剧、手工艺品和美食。中国的传统节日，如春节、中秋节和端午节，都有着丰富的文化内涵和庆祝活动。
中国也是联合国安理会五个常任理事国之一，对国际事务有重要的影响。同时，它也在全球环境保护、可持续发展和其他全球性问题上扮演着重要角色。""")

sum_models = [
    "csebuetnlp/mT5_multilingual_XLSum",
    "heack/HeackMT5-ZhSum100k",
    "yihsuan/best_model_0427_small_long",
]

print(raw_text_for_sum)
# Out:
# 中国，全称中华人民共和国，是位于东亚的一个国家，拥有世界上最多的人口。它的历史可以追溯到几千年前，是世界上最古老的文明之一，拥有丰富的文化遗产和传统。中国的地理特征非常多样，从东部的沿海平原到西部的高山和高原，如青藏高原和喜马拉雅山脉。
# 中国的政治体制是社会主义共和国，由中国共产党领导。首都是北京，其他主要城市包括上海、广州和深圳。中国经济在过去几十年里迅速发展，现在是世界上最大的经济体之一。它在制造业、科技和贸易方面具有显著地位。
# 中国的文化非常丰富多彩，包括传统的文学、音乐、舞蹈、戏剧、手工艺品和美食。中国的传统节日，如春节、中秋节和端午节，都有着丰富的文化内涵和庆祝活动。
# 中国也是联合国安理会五个常任理事国之一，对国际事务有重要的影响。同时，它也在全球环境保护、可持续发展和其他全球性问题上扮演着重要角色。

# %%
for model in sum_models:
    print(f"【测试】【{model}】")
    tokenizer = AutoTokenizer.from_pretrained(model, legacy=False, use_fast=False)
    pipe = pipeline(task="summarization", model=model, tokenizer=tokenizer, min_length=10, max_length=150)
    result = pipe(raw_text_for_sum)
    print(result)
    print("-----------------------------------------------------------------------------")
# Out:
# 【测试】【csebuetnlp/mT5_multilingual_XLSum】
# [{'summary_text': '中国是世界上最大的经济体,也是联合国安理会五个常任理事国之一。'}]
# -----------------------------------------------------------------------------
# 【测试】【heack/HeackMT5-ZhSum100k】
# [{'summary_text': '中国是联合国安理会五个常任理事国之一'}]
# -----------------------------------------------------------------------------
# 【测试】【yihsuan/best_model_0427_small_long】
# [{'summary_text': '中国,全称中华人民共和国,是位于东亚的一个国家,拥有世界上最多的人口。中国的地理特征非常多样,从东部的沿海平原到西部的高山和高原,如青藏高原和喜马拉雅山脉。中国的政治体制是社会主义共和国,由中国共产党领导。首都是北京,其他主要城市包括上海、广州和深圳。中国经济在过去几十年里迅速发展,现在是世界上最大的经济体之一。中国的政治体制是社会主义共和国,由中国共产党领导。首都是北京,其他主要城市包括上海、广州和深圳。'}]
# -----------------------------------------------------------------------------
